# %%
import pandas as pd
import numpy as np

# %%
mineral_prices = pd.read_excel('mineral_prices.xlsx', sheet_name='mineral_prices')
mineral_prices_add = pd.read_excel('mineral_prices.xlsx', sheet_name='mineral_prices_add')

# %%
mineral_prices.head()
# Out:
#    Year    Aluminium     Antimony      Arsenic    Asbestos      Baryte  \
# 0  1935  8808.296094  6101.930309  2033.976770  722.818191  124.391968
# 1  1936  8942.773897  5362.302393  2000.357319  638.769564  129.434885
# 2  1937  8371.243234  6488.553993  1798.640615  605.150113  130.611566
# 3  1938  8572.959939  5311.873217  1697.782262  504.291761  149.606556
# 4  1939  8707.437742  5379.112118  1714.591988  722.818191  118.172369
#
#     Bentonite     Berillium       Bismuth        Boron  ...  Thorium  \
# 0  146.748902  4.975679e+06  46226.744768  1030.436165  ...      NaN
# 1  167.088670  4.908440e+06  43369.091455  1010.264495  ...      NaN
# 2  161.541461  4.202431e+06  41856.216171  1001.859632  ...      NaN
# 3  153.136598  4.286480e+06  44881.966738  1116.165765  ...      NaN
# 4  168.097254  4.353719e+06  47907.717304  1511.194311  ...      NaN
#
#            Tin   Titanium      Tungsten   Uranium      Vanadium   Vermiculite  \
# ...

# %%
mineral_prices_add.head()
# Out:
#   mineral_commodity         2016         2017         2018         2019  \
# 0         aluminium   356.749815   347.852595   340.055663   334.246116
# 1     antimony_mine  6577.574713  6413.532222  6269.776289  6162.662764
# 2     arsenic_white  1293.218079  1695.781401  1519.623745  2015.921887
# 3          asbestos  2129.350458  2032.763602  1774.665492  1566.778669
# 4            baryte   208.475673   194.580045   187.030615   188.013440
#
#          2020     2021    2022
# 0   330.97120   326.08   320.0
# 1  6102.28150  8152.00  9000.0
# 2  1561.77035  1304.32  1500.0
# 3  1706.57025  1834.20  1820.0
# 4   206.85700   305.70   500.0

# %%
mineral_prices.isna().sum()
# Out:
# Year             0
# Aluminium        3
# Antimony         3
# Arsenic          3
# Asbestos         3
#                 ..
# Vanadium         3
# Vermiculite     24
# Wollastonite    28
# Zinc             3
# Zirconium        3
# Length: 75, dtype: int64

# %%
for value in mineral_prices.values:
    if np.isnan(value).any():
        value[np.isnan(value)] = mineral_prices_add
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# ...

# %%
for data in mineral_prices.values:
    for point in data:
        if np.isnan(point):
            point =
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...
