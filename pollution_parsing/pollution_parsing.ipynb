# %%
# import dependencies
import pandas as pd

# %%
# read in excel. excel is stored in the same directory as this file so only the file name is needed.
df = pd.read_excel("pollution_parsing.xlsx")

# %%
# view first 5 lines
df.head()
# Out:
#   ISO Code  Al(III) - Aluminium Emitted_human_tox_human_tox  \
# 0      AFG                                                0
# 1      ALB                                                0
# 2      DZA                                                0
# 3      AND                                                0
# 4      AGO                                                0
#
#    Co(II) - Cobalt Emitted_human_tox_human_tox  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    Cs(I) - Cesium Emitted_human_tox_human_tox  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    Fe(II) - Iron Emitted_human_tox_human_tox  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#    Fe(III) - Iron Emitted_human_tox_human_tox  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    Mn(II) - Manganese Emitted_human_tox_human_tox  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Se(IV) - Selenium Emitted_human_tox_human_tox  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    Sn(II) - Tin Emitted_human_tox_human_tox  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#    Sr(II) - Strontium Emitted_human_tox_human_tox  ...  \
# 0                                               0  ...
# 1                                               0  ...
# 2                                               0  ...
# 3                                               0  ...
# 4                                               0  ...
#
#    Ni(II) - Nickel Eco Toxicity  Pb(II) - Lead Eco Toxicity  \
# 0                  3.694707e+07                3.359725e+06
# 1                  3.694707e+07                3.359725e+06
# 2                  3.694707e+07                3.359725e+06
# 3                  3.694707e+07                3.359725e+06
# 4                  3.694707e+07                3.359725e+06
#
#    Sb(III) - Antimony Eco Toxicity  Sb(V) - Antimony Eco Toxicity  \
# 0                     4.692627e+07                   3.825187e+07
# 1                     4.692627e+07                   3.825187e+07
# 2                     4.692627e+07                   3.825187e+07
# 3                     4.692627e+07                   3.825187e+07
# 4                     4.692627e+07                   3.825187e+07
#
#    Se(IV) - Selenium Eco Toxicity  Sn(II) - Tin Eco Toxicity  \
# 0                    8.129279e+06               3.478829e+06
# 1                    8.129279e+06               3.478829e+06
# 2                    8.129279e+06               3.478829e+06
# 3                    8.129279e+06               3.478829e+06
# 4                    8.129279e+06               3.478829e+06
#
#    Sr(II) - Strontium Eco Toxicity  Tl(I) Thallium - Eco Toxicity  \
# 0                     1.542249e+08                   3.529758e+07
# 1                     1.542249e+08                   3.529758e+07
# 2                     1.542249e+08                   3.529758e+07
# 3                     1.542249e+08                   3.529758e+07
# 4                     1.542249e+08                   3.529758e+07
#
#    V(V) - Vanadium Eco Toxicity  Zn(II) - Zinc Eco Toxicity
# 0                  5.472568e+07                1.866137e+07
# 1                  5.472568e+07                1.866137e+07
# 2                  5.472568e+07                1.866137e+07
# 3                  5.472568e+07                1.866137e+07
# 4                  5.472568e+07                1.866137e+07
#
# [5 rows x 37 columns]

# %%
# for loop that iterates through each column name
for col in df.columns:
    # create new dataframe object that contains only the ISO column and the pollutants of interest (there will also be a double ISO df but this is just a quick script)
    new_df = df[['ISO Code', col]]
    # rename columns so that year is included
    new_df.columns = ['ISO', '2021']
    # export columns to csv, named after pollutant
    new_df.to_csv(f"{col}.csv",index=False)
